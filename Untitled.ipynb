# %%
import numpy as np
import tensorflow as tf
import pandas as pd
# Out:
# C:\Users\Randy\anaconda3\envs\IBM Data Science Project\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Randy\anaconda3\envs\IBM Data Science Project\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\Randy\anaconda3\envs\IBM Data Science Project\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
hdb_string = "HDBdata with district_coord_dist_full.csv"
df = pd.read_csv(hdb_string, na_values=0)

# %%
df.head()
# Out:
#    District      month        town flat_type block        street_name  \
# 0        20  1 01 2017  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10
# 1        20  1 01 2017  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4
# 2        20  1 01 2017  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5
# 3        20  1 01 2017  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10
# 4        20  1 01 2017  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5
#
#   storey_range  floor_area_sqm      flat_model  remaining_lease  resale_price  \
# 0     10 TO 12            44.0        Improved               61      232000.0
# 1     01 TO 03            67.0  New Generation               60      250000.0
# 2     01 TO 03            67.0  New Generation               62      262000.0
# 3     04 TO 06            68.0  New Generation               62      265000.0
# 4     01 TO 03            67.0  New Generation               62      265000.0
#
#      Price/sqm  Latitude   Longitude       mrtdist
# ...

# %%
df.drop(columns='lease_commence_date', inplace = True)

# %%
df.month = pd.to_datetime(df.month)

# %%
df_month = df.set_index('month')

# %%
df_month.groupby(by = 'street_name').sum()
# Out:
#                 District  floor_area_sqm  remaining_lease  resale_price  \
# street_name
# ADMIRALTY DR       12366         52517.0            37247  1.945914e+08
# ADMIRALTY LINK      9882         35604.0            31133  1.302255e+08
# AH HOOD RD           324          3190.0             1635  1.764489e+07
# ALJUNIED AVE 2        14            86.0               77  3.750000e+05
# ALJUNIED CRES       2716         14107.0            11529  6.616513e+07
# ...                  ...             ...              ...           ...
# YUNG KUANG RD       1628          7638.0             6961  3.695044e+07
# YUNG LOH RD          506          2602.0             1748  8.909000e+06
# YUNG PING RD         880          5868.0             3072  2.185578e+07
# YUNG SHENG RD       2178         10448.0             8018  4.127466e+07
# ZION RD               33          1284.0              593  8.870000e+06
#
#                    Price/sqm    Latitude     Longitude       mrtdist
# street_name
# ...

# %%
df.groupby(by=['month','town','street_name']).count()
# Out:
#                                          District  flat_type  block  \
# month      town       street_name
# 2017-01-01 ANG MO KIO ANG MO KIO AVE 1          7          7      7
#                       ANG MO KIO AVE 10        15         15     15
#                       ANG MO KIO AVE 3         13         13     13
#                       ANG MO KIO AVE 4          8          8      8
#                       ANG MO KIO AVE 5          5          5      5
# ...                                           ...        ...    ...
# 2021-01-11 YISHUN     YISHUN ST 51             23         23     23
#                       YISHUN ST 61              6          6      6
#                       YISHUN ST 71              2          2      2
#                       YISHUN ST 72              4          4      4
#                       YISHUN ST 81              5          5      5
#
#                                          storey_range  floor_area_sqm  \
# month      town       street_name
# ...

# %%
df.groupby(by=['month','street_name']).count().iloc[:,:1]
# Out:
#                             District
# month      street_name
# 2017-01-01 ADMIRALTY DR            4
#            ADMIRALTY LINK          1
#            ANCHORVALE DR           1
#            ANCHORVALE LANE         1
#            ANCHORVALE LINK         4
# ...                              ...
# 2021-01-11 YISHUN ST 81            5
#            YUAN CHING RD           3
#            YUNG KUANG RD           1
#            YUNG PING RD            1
#            YUNG SHENG RD           4
#
# [24503 rows x 1 columns]
